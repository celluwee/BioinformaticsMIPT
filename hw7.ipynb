# %% [markdown]
# ## Задание 1

# %% [markdown]
# Выберем следующие последовательности Spike белка коронавируса из файла (до выравнивания)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# После выравнивания с помощью ClustlW замечаем, что наиболее консервативная часть - это центральная в последовательности, в то время как в начале и в конце могут быть достаточно большие делеции, что не противоречит логике
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Выбираем метод Maximum Likelihood и 100 бустрепных реплик. Результат:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Попробуем поменять метод, чтобы получить лучшее дерево. Согласно МЛ модели нам нужен T92 — Tamura 3-parameter.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Действительно получаем более хорошие бустреп-значения для узлов, дерево остается точно таким же
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Можем говорить о том что гены располагаются на очень маленькой эволюционной дистанции (мутации молодые), визуально выделяются группы наиболее близкородственных

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Выберем ген ACTB actin beta, который участвует в формировании цитоскелета, клеточном делении, внутриклеточном транспорте и тд

# %% [markdown]
# С помощью NCBI выберем 7 ортологичных по нему организмов (Homo sapiens
# Pan troglodytes
# Mus musculus
# Meriones unguiculatus
# Danio rerio
# Dicentrarchus labrax
# Engystomops pustulosus).

# %% [markdown]
# Далее выполним выравнивание нуклеотидных последовательностей ClustlW и построим филогенетическое дерево методом Maximum Likelihood, установим количество 100 реплик

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Получим следующий результат:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# По дереву снова подтверждаем ортологичность генов. Наиболее близким к человеку оказывается шимпанзе (Pan troglodytes), что соответствует ожиданиям. Наиболее далеким филогенетически будет амфибия Тунгарская лягушка (Engystomops pustulosus), причем эволюционная дистанция превышает 0.3

# %% [markdown]
# Проведем еще один эксперимента, согласно MEGA, лучшее дерево нам построит алгоритм Kimura2, представим результат ниже.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Видим, что расположение веток не поменялось, однако результат хуже, получаем узел с bootstrap-значением 75%, когда было 96%, что означает, что он повторяется в меньшей доле реплик
